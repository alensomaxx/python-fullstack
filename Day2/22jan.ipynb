# %%
a=int(input())
match a:
    case 0:   
        print(0)
    case 1:
        print(1)
    case 2:
        print(2)
    case _:
        print("default")
# Out:
# 1

# %%
n=int(input())
for i in range(1,n+1):
    if(i%2!=0):
        continue
    print(i)

# %%
def fun(a,b):
    a+=1
    b+=1
    print("hello")
    print(a+b)
    return a,b


fun(3,4)
# Out:
# hello
# 9
# (4, 5)

# %%
def fun(a:int,b:int)->int:
    
    print("hello")
    print(a,b)
   


fun(3,'4')
# Out:
# hello
# 3 4

# %%
#  *b  (*)is used to take multiple values 
def fun(a,*b):
    print(a,b)
fun(3,4,5,6,7,8,9,0)
# Out:
# 3 (4, 5, 6, 7, 8, 9, 0)

# %%
n=int(input())
rev=0
while(n!=0):  #346 ,34,3,0
    rem=n%10   #6,4,3
    rev=rev*10+rem #0*10+6=6,6*10+4=64,64*10+3=643
    n=n//10  #n=34 , n=3,n=0

# %%
x=lambda a,b:a+b
print(x(2,3),x(5,6))
# Out:
# 5 11

# %%
l=["abc","def","ghi","jkl"]
print(max(l,key=len))  #key accepts the function   ,, max accepts the multiple values
# Out:
# abc

# %%
l=[[2,3],[4,5,6],[8,9,0]]
l.sort()
print(l)
# Out:
# [[2, 3], [4, 5, 6], [8, 9, 0]]

# %%
l=[[2,3],[4,5,6],[8,9,0]]
l.sort(key=lambda x:x[-1]*x[-2],reverse=True)
print(l)

# %%
##leap year with conditions  three conditions are used to identify leap years:

"""The year can be evenly divided by 4, is a leap year, unless:
The year can be evenly divided by 100, it is NOT a leap year, unless:
The year is also evenly divisible by 400. Then it is a leap year."""
def is_leap(year):
    leap=False
    if(year%4==0 and year%100!=0) or (year%4==0 and year%400==0):
        leap=True
    return leap

year=int(input())
print(is_leap(year))
# Out:
# False

# %% [markdown]
# RECURSION :- LEARN how to trace the code , convert for ,while loop into recursion

# %%
def fun(n):
    if n==0:
        return
    fun(n-1)
    print(n)
    fun(n-1)
fun(3)
# Out:
# 1
# 2
# 1
# 3
# 1
# 2
# 1
