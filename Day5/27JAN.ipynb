# %% [markdown]
# inheritance
# super fxn. -> checks the next value in the mro function
# mro --> gives tuple value ,property of class . for every class mro is stored ,parameter (method re...)
#
# **integer takes 8 bytes in python
#
# array is better than using a list.
# Dender method :
#             __init__ intitalises the object ,doesnot create any object
# magic methods

# %%
l=[2,3,4]
l.append(l)
print(l)
# Out:
# [2, 3, 4, [...]]

# %%
class A:
    def __str__(self):
        return "this is str"
    def __repr__(self):
        return "this is repr"
a=A()

print(a)
# Out:
# this is str

# %%
try:
    l=[4,5]
    print(l[2])
except:
    print("index error")
# Out:
# index error

# %%
try:
    try:
        a=4
        b=0
        print(a/b)
    except IndexError:
        print("working")
    except ZeroDivisionError:
        print("this is wokring" )
except:
    print("outer is working")
# Out:
# this is wokring
